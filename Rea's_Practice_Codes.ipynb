# %% [markdown]
# <a href="https://colab.research.google.com/github/ReaMarie1163/GCI-Utokyo-Practice-Python/blob/main/Rea's_Practice_Codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***OH MY GOD GONNA START AGAIN ARGH***

# %% [markdown]
# **BASICS PYTHON IM GONNA TRY CODING FROM MEMORY😀**

# %%
#Basic put out a text
#print('insert text') very important

print('Hello World')
# Out:
# Hello World

# %%
print('Hello, its me again and Im coding again because my github repository isnt public and Idk github so my previous codes were gone')
# Out:
# Hello, its me again and Im coding again because my github repository isnt public and Idk github so my previous codes were gone

# %%
#Introduce myself
print('Hi, this is Rea. 22 years old. A failure.')
# Out:
# Hi, this is Rea. 22 years old. A failure.

# %% [markdown]
# **ARITHMETIC OPERATIONS**

# %%
#ADDITION
print(5+3)
print('Rea+Marie=8 values in total')
# Out:
# 8
# Rea+Marie=8 values in total

# %%
#SUBTRACTION
print(8-5)
print('3 is the total number of values in my First name')
# Out:
# 3
# 3 is the total number of values in my First name

# %%
#MULTIPLICATION
print(5*3)
print('15 is the total number of values in  my full name')
# Out:
# 15
# 15 is the total number of values in  my full name

# %%
#DIVISION NORMAL DIVISION
print(27.5/2)
# Out:
# 13.75

# %%
#DIVISION //
#FLOOR DIVISION, REMOVES DECIMAL, NO ROUND OFF
print(27.5//2)
# Out:
# 13.0

# %%
#DIVISION REMAINDER
#Honestly not sure abt this
print(27.5%2)
# Out:
# 1.5

# %% [markdown]
# **PEMDAS OR BODMAS**

# %%
#Priority: Multiplication>Addition
print(1+2*3)
# Out:
# 7

# %%
#Priority: Addition inside parentheses>multiplication
print((1+2)*3)
# Out:
# 9

# %%
#Priority: Exponentiation>Mulitplication
print (2*2**3)
# Out:
# 16

# %% [markdown]
# **STORING DATA AS VARIABLES**

# %%
#Sample
x=1 # x is the variable
y=2 # y is the variable
print(x+y)
# Out:
# 3

# %%
#Assigning
x=1
print(x)
# Out:
# 1

# %%
#Reassigning x+2 to x
x=x+2 #THE X HERE ADDED TO 2 DEPENDS ON THE CODE'S PREVIOUS X
print(x)
# Out:
# 3

# %%
#words
word='hello'
print(word)
# Out:
# hello

# %% [markdown]
# **BASIC DATA TYPES**

# %%
#int = integers
# float = floating point numbers/deciimal
#str = string, name or text
#bool= true or false value

# %%
#int type(integer) #DI KO GETS
num=1
print(type(num))
# Out:
# <class 'int'>

# %%
#float type(decimal)
num=1.0
print(type(num))
# Out:
# <class 'float'>

# %%
#Calculatiom between int and float->float type
num=1+1.0
print(type(num))
#FLOAT COS PYTHON KEEPS DECIMALS AS TO NOT LOSE INFORMATION
# Out:
# <class 'float'>

# %%
#Divide two int types
num=1/1
print(type(num))
# Out:
# <class 'float'>

# %%
#use another variable but not num
lol=1/1
print(type(lol))
#CODE STILL WORKS AND IT CAN BE ANYTHING
# Out:
# <class 'float'>

# %% [markdown]
# **TEXT DATA: str Type**

# %%
string='Python'
print(type(string))
print(string)
# Out:
# <class 'str'>
# Python

# %%
str1='Hello'
str2='World'
print(str1+","+str2) #ADDIING A COMMA IN BETWEEN
# Out:
# Hello,World

# %%
#Repeat
text="Hello" # define the text
repeated = text * 7 #repeat the text variable 3x
print(repeated) #print the repeated text variable
# Out:
# HelloHelloHelloHelloHelloHelloHello

# %%
#Length of the string #Gives u the number of letters
string='Python'
print(len(string))
# Out:
# 6

# %%
#If you want to grab a letter out of a string, you use its position or its index
#Index start counting from 0. O as the first letter of the first letter on the word
#Get the first character

text="Apple"
part=text[4] #0th index
print(part)
# Out:
# e

# %%
#Extracting a substring from a string
text="Apple"
part=text[0:3] #characters from 0 to 2 are not THE ONES WE GET (index 3 not included)
print(part)
# Out:
# App

# %%
#Extracring a subtstring from a string
text="Marie"
part=text[1:4] #starts at 1th index and ends at 3rd index, before the 4th index
print(part)
# Out:
# ari

# %%
#f-string EMBEDD THINGS OR VARIABLED IN THE {}
name="Matsuo"
age=25
message=f"My name is{name}and I am {age}years old" #You can embed vairables inside {}
print(message)
# Out:
# My name isMatsuoand I am 25years old

# %% [markdown]
# **TYPECASTING AKA CHANGING THE TYPE**

# %%
#TYPECASTING SAMPLE 1
x='3.14'# pag nilagyan ng '' thats when we know that its a text
print(type(x))
# Out:
# <class 'str'>

# %%
#TYPECASTING SAMPLE 2
y=float(x) #we basically turned the X FROM THE PREVIOUS CODE TO A FLOAT USING THIS Y VARIABLE
print(type(y))
# Out:
# <class 'float'>

# %%
#TYPECASTING SAMPLE 3
z= int(y)
print(z) #so si 3.14 na string and text ginawa natin siyang 3 lang by turning it into an int
# Out:
# 3

# %% [markdown]
# **SOLUTION**
#
# 1. DEFINE STRING OR TEXT VARIABLE
# 2. TURN TO FLOAT COS IT HAS DECIMAL
# 3. TURN TO INT int(insert variable)

# %% [markdown]
# **TYPECASTING BOOLEAN**

# %%
#Converting from bool to int
#True->int()->1
x=True
print(int(x))
#why the numbers are 1 and 0 respectively? are other digits allowed?
# Out:
# 1

# %%
#Converting from bool to int
#False->int()->0
x=False
print(int(x))
# Out:
# 0

# %%
#Converting from int to bool
#2->bool()->true
print(bool(2))
# Out:
# True

# %%
#Converting from in to bool
#0.0->bool()->false
print(bool(0.0))
# Out:
# False

# %%
#TRY KO
#float to bool
x=3.14
print(bool(x)) #ANY NUMBER THAT ISNT 0 WILL BECOME TRUE
# Out:
# True

# %%
print(bool(3.14))
# Out:
# True

# %%
#str->int->float->bool
x='7.89'
print(type(x))
# Out:
# <class 'str'>

# %%
y=float(x)
print(type(y))
# Out:
# <class 'float'>

# %%
z=int(y)
print(z)
# Out:
# 7

# %% [markdown]
# **COLLECTIONS**
# -> Allow you to manage values together, there are types of lists, tuples, dictionaries, etc.
#
# Ordered Position-
# - [0]->1
# - [1]->2
# - [2]->3
# Ex: Lists and Tuplets
#
# **Keyword Management**
# ->organization by keyword
# -> every piece of data get its own unique label

# %% [markdown]
# **LIST**
#
# ->uses brackets to manage values(elements) in order (indices).
#
# ->An elements can be extracted and replaced by specifying the index.
#
# -> Create one with a bracket, and each item inside is called an element, separated by a comma.
#
# ->index, ever single element gets a numbered position, a unique address
#
# ->**In python, we start counting from zero**

# %%
#List sample

menu= ['salad','soup','steak','cake']
print(menu[0])
#0-> salad, 1->soup, 2->steak, 3->cake
#backwards count from -1
# Out:
# salad

# %%
#List sample backwards
print(menu[-1])
# Out:
# cake

# %%
#Interchange element
menu[-1]='pudding'
print(menu)
# Out:
# ['salad', 'soup', 'steak', 'pudding']

# %% [markdown]
# **NOTES**
#
# 1.Programming language needs to follow certain rules = syntax
#
# 2.Writing comments between lines can be helpful to understand the code better
#
# 3.Storing data in variables and understanding their types (int,string,bool)
#
# 4.Organizing groups of data using collections like lists, tuples, dictionaries.

# %% [markdown]
# Create a program to calculate BMI from height and weight. BMI=weight(kg)/(height(m))^2

# %%
#Input example
weight=50 #kg
height=165 #cm
height= height/100 #1.65cm
bmi= weight / height **2
print(bmi)
# Out:
# 18.36547291092746

# %% [markdown]
# PRACTICE QUESTIONS
#
# > Write a list that includes all prime numbers less than 10.

# %%
#Prime numbers less than 10
primes=[2,3,5,7]
print(primes)
# Out:
# [2, 3, 5, 7]

# %%
#Tuple prime numbers less than 10
primes=(2,3,5,7)
print(primes)
# Out:
# (2, 3, 5, 7)

# %% [markdown]
# Write a dictionary whose key is the string 'name' and whose value is a string containing your name

# %%
my_dict={'name':'rea'}
print(my_dict)
# Out:
# {'name': 'rea'}

# %% [markdown]
# TUPLE IS DIFFERENT FROM LIST

# %% [markdown]
# #**PRE-LECTURE PRACTICE**

# %%
#STRING
print("HI")
# Out:
# HI

# %%
x = "Hello"
y = "Rea"
print(x +y)
# Out:
# HelloRea

# %%
a = 1
b = 2

#addition
print("Addition:", a + b) #when you want to print text + number, you put the text in "" and then add comma

#subtraction
print("Subtraction:", b-a)

#multiplication
print("Multiplication:", a*b)

#division
print("Division:", a/b)

#integer division
print("Integer Division:", a//b)

# remainder
print("Remainder:", a%b)

#Exponential
print("Exponential:", a**2)
# Out:
# Addition: 3
# Subtraction: 1
# Multiplication: 2
# Division: 0.5
# Integer Division: 0
# Remainder: 1
# Exponential: 1

# %% [markdown]
# Create a program to calculate BMI from height and weight. BMI=weight(kg)/(height(m))^2

# %%
#input example
weight=50 #kg
height=165 #cm
bmi = weight /((height/100)**2)
print(bmi)
# Out:
# 18.36547291092746

# %% [markdown]
# Let's assume that an integer is stored in the variable x. Create a program that will display (print) 0 if x is even and 1 if x is odd

# %%
#insert code

# %% [markdown]
# Write a list that includes all prime numbers less than 10

# %%
primes_list=[2,3,5,7]
print(primes_list)
# Out:
# [2, 3, 5, 7]

# %%
primes_tuple=(2,3,5,7)
print(primes_tuple)
# Out:
# (2, 3, 5, 7)

# %% [markdown]
# LIST VS TUPLE
#
# list can be interchanged, tuple is as is

# %%
print(primes_list[0])
# Out:
# 2

# %%
primes_list[-4]=1
print(primes_list)
# Out:
# [1, 3, 5, 7]

# %%
name = {'name':'Taro'}
print(name)
# Out:
# {'name': 'Taro'}

# %% [markdown]
# IF STATEMENT

# %%
a=4
if a%2==0:
  print("Even")
else:
  print("Odd")
# Out:
# Even

# %% [markdown]
# Write a program of your choice using a for loop

# %%
sample_list=[1,2,3,4,5]
for i in sample_list: #i is just a name and you could rename it anything
  print(i%2)
# Out:
# 1
# 0
# 1
# 0
# 1

# %% [markdown]
# Practice Questions
# Define a function f that takes a string x with a length of 1 or more as an argument and returns the last character of x.

# %%
x ='python'

# %%
x = 'python'
def last_char(x):
  return x[-1]
  last_char(x)
print(last_char(x))
# Out:
# n

# %% [markdown]
# Define a function f that takes a dictionary as an argument x and returns the number of keys stored in x

# %%
x = {"a":1, "b":2, "c":3, "d":4, "e":5}

def num_keys(x):
    return len(x.keys())

print(num_keys(x))

#Pre-Lecture notebook code is
#x = {"a":1, "b":2, "c":3, "d":4, "e":5}
#def num_keys(x):
#return len(x.keys())
#num_keys(x)
# Out:
# 5

# %% [markdown]
# Define a function f that takes a list as an argument x and returns a list of elements of x in reverse order. However, achieve this without using functions like reversed, but using loops or list slicing

# %%
x=[3,9,7,1,0]

def f(x):
  y=[]
  for i in range(len(x)):
      y.append(x[-i-1])
  return y
  print(f(x))
